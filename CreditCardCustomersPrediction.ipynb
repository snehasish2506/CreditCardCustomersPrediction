# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from matplotlib.ticker import MaxNLocator

# %%
# Connect dataset with panda

dataCreditCard = pd.read_excel('/content/CreditCardCustomersPrediction.xlsx')

# %%
# Checking total number of columns and rows

dataCreditCard.shape
# Out:
# (10127, 23)

# %% [markdown]
# **Observation**
#
# As per analysis, I have found 10127 rows and 23 columns

# %%
# Checking null values

dataCreditCard.isnull().sum()
# Out:
# CLIENTNUM                                                                                                                             0
# Attrition_Flag                                                                                                                        0
# Customer_Age                                                                                                                          0
# Gender                                                                                                                                0
# Dependent_count                                                                                                                       0
# Education_Level                                                                                                                       0
# Marital_Status                                                                                                                        0
# ...

# %% [markdown]
# **Observation**
#
# There are **no null value** found in the dataset

# %%
dataCreditCard.describe()
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count  1.012700e+04  10127.000000     10127.000000    10127.000000
# mean   7.391776e+08     46.325960         2.346203       35.928409
# std    3.690378e+07      8.016814         1.298908        7.986416
# min    7.080821e+08     26.000000         0.000000       13.000000
# 25%    7.130368e+08     41.000000         1.000000       31.000000
# 50%    7.179264e+08     46.000000         2.000000       36.000000
# 75%    7.731435e+08     52.000000         3.000000       40.000000
# max    8.283431e+08     73.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# ...

# %%
# Checking the columns name

dataCreditCard.columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'],
#       dtype='object')

# %%
# Checking datatypes

dataCreditCard.dtypes
# Out:
# CLIENTNUM                                                                                                                               int64
# Attrition_Flag                                                                                                                         object
# Customer_Age                                                                                                                            int64
# Gender                                                                                                                                 object
# Dependent_count                                                                                                                         int64
# Education_Level                                                                                                                        object
# ...

# %% [markdown]
# <center>
#
# |**Field Name**|**Data types**|
# |---------------:|---------------:|
# |CLIENTNUM |numerical|
# |Attrition_Flag |object|
# |Customer_Age |numerical|
# |Gender |object|
# |Dependent_count	|numerical|
# |Education_Level |object|
# |Marital_Status    |object|
# |Income_Category  |object|
# |Card_Category |object|
# |Months_on_book |numerical|
# |Total_Relationship_Count |numerical|
# |Months_Inactive_12_mon   |numerical|
# |Contacts_Count_12_mon | numerical|
# |Credit_Limit | numerical|
# |Total_Revolving_Bal| numerical|
# |Avg_Open_To_Buy |numerical|
# |Total_Amt_Chng_Q4_Q1|numerical|
# |Total_Trans_Amt|numerical|
# |Total_Trans_Ct |numerical|
# |Total_Ct_Chng_Q4_Q1|numerical|
# |Avg_Utilization_Ratio|numerical
# |Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1|numerical|
# |Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2 | numerical|
#
# <center>

# %%
plt.figure(figsize=(15,8))
ax = sns.countplot(data=dataCreditCard, x = 'Customer_Age')
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
for p in ax.patches:
  ax.annotate('{}'.format(p.get_height()), (p.get_x()-0.1, p.get_height()+10))
plt.show()

# %%
dataCreditCard['Attrition_Flag'].value_counts()
plt.figure(figsize=(15,8))
ax = sns.countplot(dataCreditCard["Attrition_Flag"])
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
for p in ax.patches:
  ax.annotate('{}'.format(p.get_height()), (p.get_x()+0.4, p.get_height()+10))
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **Observation**
#
# As per analysis there are **8500** Existing Customer and **1627** Attrited Customer

# %%
plt.figure(figsize=(15,9))
gender = dataCreditCard['Gender'].value_counts()
plt.pie(gender,labels = gender.index, autopct='%.0f%%')
# plt.pie(gender,labels = gender.index, autopct=lambda p:'{},{}%'.format((10127*p/100,p)))
plt.show()

# %% [markdown]
# **Observation**
#
# I have found **4769 (47%)** males and **5358 (53%)** females in the dataset

# %%
dataCreditCard['Dependent_count'].value_counts()
plt.figure(figsize=(15,9))
ax = sns.countplot(dataCreditCard['Dependent_count'])
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
for p in ax.patches:
  ax.annotate('{}'.format(p.get_height()), (p.get_x()+0.3, p.get_height()+0.01))
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# The **904** customer has no dependents, while the following customers : **1838**, **2655**, **2732**, **1574**, **424**, who have **1**, **2**, **3**, **4** and **5** dependent respectively.

# %%
dataCreditCard['Education_Level'].value_counts()
plt.figure(figsize=(15,9))
ax = sns.countplot(dataCreditCard['Education_Level'], hue =dataCreditCard['Gender'])
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
for p in ax.patches:
  ax.annotate('{}'.format(p.get_height()), (p.get_x()+0.1, p.get_height()+0.01))
  plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## **Observation**
#
# Maximum numbers of male and female are graduate
#
# While minimum numbers of male and female are doctorate

# %%
dataCreditCard['Marital_Status'].value_counts()
plt.figure(figsize=(15,9))
martialStatus = dataCreditCard['Marital_Status'].value_counts()
plt.pie(martialStatus,labels = martialStatus.index, autopct='%.0f%%')
plt.show()

# %% [markdown]
# **Observation**
#
# According to my analysis,
# **7%** of your customers were **divorced**.
# **46%** customers reported being **married**.
# **39%** of our customers were **single**.
# **7%** customers had an **unknown** marital status.

# %%
plt.figure(figsize=(15,9))
incomeCategory = dataCreditCard['Income_Category'].value_counts()
plt.pie(incomeCategory,labels = incomeCategory.index, autopct='%.0f%%')
plt.show()

# %% [markdown]
# **Observation**
#
# **7%** customer under **USD 120K+** income category
#
# **18%** customer under **USD 40K-USD 60K** income category
#
# **14%** customer under **USD 60K- USD 80K** income category
#
# **15%** customer under **USD 80K-USD 120K** income category
#
# **35%** customer under **Less than USD 40K** income category
#
# **11%** customer income category was **Unknown**

# %%
dataCreditCard['Card_Category'].value_counts()
plt.figure(figsize=(15,9))
ax = sns.countplot(x='Card_Category', data=dataCreditCard, hue='Gender')
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
for p in ax.patches:
  ax.annotate('{}'.format(p.get_height()), (p.get_x()+0.1, p.get_height()+0.01))
plt.show()

# %% [markdown]
# **Observation**
#
# Total **9436** customers had **Blue** card, **555** customer has **Silver** card, **116** customer had **Gold** card and **20** customer had **Platinum** card

# %%
dataCreditCard.hist()
# dfused.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f54cc242bb0>,
# ...
#       dtype=object)

# %%
pearsons_coefficient = np.corrcoef(dataCreditCard['Total_Trans_Amt'], dataCreditCard['Total_Trans_Ct'])
print(pearsons_coefficient)
# Out:
# [[1.         0.80719203]
#  [0.80719203 1.        ]]

# %%
# int64, object, float64

categoricalCols=[]
numericalCols=[]

for i in dataCreditCard.columns:
  if (dataCreditCard[i].dtypes == 'int64')  or (dataCreditCard[i].dtypes == 'float64'):
    numericalCols.append(i)

print(numericalCols)
# Out:
# ['CLIENTNUM', 'Customer_Age', 'Dependent_count', 'Months_on_book', 'Total_Relationship_Count', 'Months_Inactive_12_mon', 'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal', 'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt', 'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio', 'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1', 'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2']

# %%
plt.figure(figsize=(15,8))
ax = sns.countplot(data=dataCreditCard, x ='Customer_Age', hue='Attrition_Flag')
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
for p in ax.patches:
  ax.annotate('{}'.format(p.get_height()), (p.get_x()+0.1, p.get_height()+0.01))
plt.show()

# %%
plt.figure(figsize=(15,8))
ax = sns.countplot(data=dataCreditCard, x= 'Gender', hue = 'Attrition_Flag')
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
for p in ax.patches:
  ax.annotate('{}'.format(p.get_height()), (p.get_x()+0.1, p.get_height()+0.01))
plt.show()

# %%
plt.figure(figsize=(15,8))
ax = sns.countplot(data=dataCreditCard,x='Dependent_count', hue='Attrition_Flag')
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
for p in ax.patches:
  ax.annotate('{}'.format(p.get_height()), (p.get_x()+0.1, p.get_height()+0.01))
plt.show()

# %%
plt.figure(figsize=(15,5))
ax = sns.countplot(data=dataCreditCard,x='Education_Level', hue='Attrition_Flag')
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
for p in ax.patches:
  ax.annotate('{}'.format(p.get_height()), (p.get_x()+0.1, p.get_height()+0.01))
plt.show()

# %%
plt.figure(figsize=(15,8))
ax = sns.countplot(data=dataCreditCard,x='Card_Category',hue='Attrition_Flag')
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
for p in ax.patches:
  ax.annotate('{}'.format(p.get_height()), (p.get_x()+0.1, p.get_height()+0.01))
plt.show()

# %%
plt.figure(figsize=(15,8))
ax = sns.countplot(data=dataCreditCard,x='Marital_Status', hue='Attrition_Flag')
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
for p in ax.patches:
  ax.annotate('{}'.format(p.get_height()), (p.get_x()+0.1, p.get_height()+0.01))
plt.show()

# %%
plt.figure(figsize=(15,8))
ax = sns.countplot(data=dataCreditCard,x='Income_Category', hue='Attrition_Flag')
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
for p in ax.patches:
  ax.annotate('{}'.format(p.get_height()), (p.get_x()+0.1, p.get_height()+0.01))
plt.show()

# %%
plt.figure(figsize=(15,8))
ax = sns.countplot(data=dataCreditCard,x='Months_on_book', hue='Attrition_Flag')
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
for p in ax.patches:
  ax.annotate('{}'.format(p.get_height()), (p.get_x()+0.1, p.get_height()+0.01))
plt.show()

# %%
plt.figure(figsize=(15,8))
ax = sns.countplot(data=dataCreditCard,x='Total_Relationship_Count', hue='Attrition_Flag')	
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
for p in ax.patches:
  ax.annotate('{}'.format(p.get_height()), (p.get_x()+0.1, p.get_height()+0.01))
plt.show()

# %%
plt.figure(figsize=(15,8))
ax = sns.countplot(data=dataCreditCard,x='Months_Inactive_12_mon', hue='Attrition_Flag')
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
for p in ax.patches:
  ax.annotate('{}'.format(p.get_height()), (p.get_x()+0.1, p.get_height()+0.01))
plt.show()

# %%
plt.figure(figsize=(15,8))
ax = sns.countplot(data=dataCreditCard,x='Contacts_Count_12_mon', hue='Attrition_Flag')	
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
for p in ax.patches:
  ax.annotate('{}'.format(p.get_height()), (p.get_x()+0.1, p.get_height()+0.01))
plt.show()

# %%
plt.figure(figsize=(15,8))
ax = sns.countplot(data=dataCreditCard,x='Total_Relationship_Count', hue='Attrition_Flag')
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
for p in ax.patches:
  ax.annotate('{}'.format(p.get_height()), (p.get_x()+0.1, p.get_height()+0.01))
plt.show()

# %%
plt.figure(figsize=(15,8))
# ax = sns.countplot(data=dataCreditCard,x='Total_Trans_Ct', hue='Attrition_Flag')	
ax = sns.kdeplot(data=dataCreditCard,x='Total_Trans_Ct', hue='Attrition_Flag')
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
for p in ax.patches:
  ax.annotate('{}'.format(p.get_height()), (p.get_x()+0.1, p.get_height()+0.01))
plt.show()

# %%
plt.figure(figsize=(15,15))
sns.heatmap(dataCreditCard.corr(),annot=True)
plt.show()

# %%
ax = plt.axes((0, 0, 2.5, 2.5))
sns.scatterplot(data=dataCreditCard, 
            x="Total_Trans_Ct", 
            y="Total_Trans_Amt", 
            hue="Attrition_Flag",
            ax=ax
           );

# %%
ax = plt.axes((0, 0, 2.5, 2.5))
sns.scatterplot(data=dataCreditCard, 
            x="Total_Ct_Chng_Q4_Q1", 
            y="Total_Amt_Chng_Q4_Q1", 
            hue="Attrition_Flag",
            ax=ax
           );
